# %% [markdown]
# <a href="https://colab.research.google.com/github/vitormedeiroos/Python_mercado_financeiro/blob/main/taxas_rs_rl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib

import yfinance as yf

# %%
acoes = ['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()
for i in acoes:
  acoes_df[i]=yf.download(i, start='2010-01-01', end='2014-01-01')['Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
acoes_df
# Out:
#              GOLL4.SA  CVCB3.SA  WEGE3.SA  MGLU3.SA   TOTS3.SA  BOVA11.SA
# Date
# 2010-01-04  26.299999       NaN  2.711538       NaN   7.951558  69.370003
# 2010-01-05  26.080000       NaN  2.705621       NaN   7.818478  69.900002
# 2010-01-06  26.379999       NaN  2.720414       NaN   7.865056  70.300003
# 2010-01-07  26.660000       NaN  2.766272       NaN   7.871710  70.000000
# 2010-01-08  27.950001       NaN  2.866863       NaN   7.948231  69.480003
# ...               ...       ...       ...       ...        ...        ...
# 2013-12-20  10.070000      14.8  4.615384  0.230000  12.040456  49.910000
# 2013-12-23  10.270000      14.7  4.563609  0.229062  12.017167  50.110001
# 2013-12-26  10.250000      14.9  4.616863  0.225000  12.013840  50.040001
# 2013-12-27  10.200000      15.0  4.606508  0.231250  12.077053  50.139999
# 2013-12-30  10.480000      15.3  4.609467  0.235937  12.296636  50.240002
#
# [989 rows x 6 columns]

# %%
acoes_df['GOLL4.SA']
# Out:
# Date
# 2010-01-04    26.299999
# 2010-01-05    26.080000
# 2010-01-06    26.379999
# 2010-01-07    26.660000
# 2010-01-08    27.950001
#                 ...
# 2013-12-20    10.070000
# 2013-12-23    10.270000
# 2013-12-26    10.250000
# 2013-12-27    10.200000
# 2013-12-30    10.480000
# Name: GOLL4.SA, Length: 989, dtype: float64

# %%
acoes_df = acoes_df.rename(columns ={'GOLL4.SA': 'GOL',	'CVCB3.SA': 'CVC', 	'WEGE3.SA':'WEGE',	'MGLU3.SA': 'MGLU', 	'TOTS3.SA':'TOTVS',	'BOVA11.SA':'BOV'})

# %% [markdown]
# ####RETORNO SIMPLES - INDICADO PARA COMPARAÇAO ENTRE ATIVOS DIFERENTES - GOL COM CVC E ETC
#
# ```
# acoes_df['RS_GOL']= (acoes_df['GOL'] / acoes_df['GOL'].shift(1))-1
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
acoes_df['RS_GOL']= (acoes_df['GOL'] / acoes_df['GOL'].shift(1))-1
acoes_df['RS_CVC']= (acoes_df['CVC'] / acoes_df['CVC'].shift(1))-1
acoes_df['RS_WEGE']= (acoes_df['WEGE'] / acoes_df['WEGE'].shift(1))-1
acoes_df['RS_MGLU']= (acoes_df['MGLU'] / acoes_df['MGLU'].shift(1))-1
acoes_df['RS_TOTVS']= (acoes_df['TOTVS'] / acoes_df['TOTVS'].shift(1))-1
acoes_df['RS_BOV']= (acoes_df['BOV'] / acoes_df['BOV'].shift(1))-1

# %%
acoes_df
# Out:
#                   GOL   CVC      WEGE      MGLU      TOTVS        BOV  \
# Date
# 2010-01-04  26.299999   NaN  2.711538       NaN   7.951558  69.370003
# 2010-01-05  26.080000   NaN  2.705621       NaN   7.818478  69.900002
# 2010-01-06  26.379999   NaN  2.720414       NaN   7.865056  70.300003
# 2010-01-07  26.660000   NaN  2.766272       NaN   7.871710  70.000000
# 2010-01-08  27.950001   NaN  2.866863       NaN   7.948231  69.480003
# ...               ...   ...       ...       ...        ...        ...
# 2013-12-20  10.070000  14.8  4.615384  0.230000  12.040456  49.910000
# 2013-12-23  10.270000  14.7  4.563609  0.229062  12.017167  50.110001
# 2013-12-26  10.250000  14.9  4.616863  0.225000  12.013840  50.040001
# 2013-12-27  10.200000  15.0  4.606508  0.231250  12.077053  50.139999
# 2013-12-30  10.480000  15.3  4.609467  0.235937  12.296636  50.240002
#
#               RS_GOL    RS_CVC   RS_WEGE   RS_MGLU  RS_TOTVS    RS_BOV
# Date
# ...

# %% [markdown]
# ####TAXA DE RETORNO LOGARITMICA - COMPARAÇAO ENTRE PERIODOS DIFERENTES DA MESMA ACAO
#
#
#
# ```
# # np.log(acoes_df['GOL'][len(acoes_df)-1]/acoes_df['GOL'][0]*100
# ```

# %% [markdown]
# ##### imagem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #####cod

# %%
#acoes gol
np.log(acoes_df['GOL'][len(acoes_df)-1]/acoes_df['GOL'][0])*100
# Out:
# -92.01002749614582

# %%
#wege
np.log(acoes_df['WEGE'][len(acoes_df)-1]/acoes_df['WEGE'][0])*100
# Out:
# 53.059620875825765

# %%
#cvc
np.log(acoes_df['CVC'][len(acoes_df)-1]/acoes_df['WEGE'][0])*100
# Out:
# 173.033681110459

# %%
#taxas de retorno anual média
(acoes_df['WEGE'].mean() * 246)*100
# Out:
# 78565.41826163311

# %%
acoes_df
# Out:
#                   GOL   CVC      WEGE      MGLU      TOTVS        BOV  \
# Date
# 2010-01-04  26.299999   NaN  2.711538       NaN   7.951558  69.370003
# 2010-01-05  26.080000   NaN  2.705621       NaN   7.818478  69.900002
# 2010-01-06  26.379999   NaN  2.720414       NaN   7.865056  70.300003
# 2010-01-07  26.660000   NaN  2.766272       NaN   7.871710  70.000000
# 2010-01-08  27.950001   NaN  2.866863       NaN   7.948231  69.480003
# ...               ...   ...       ...       ...        ...        ...
# 2013-12-20  10.070000  14.8  4.615384  0.230000  12.040456  49.910000
# 2013-12-23  10.270000  14.7  4.563609  0.229062  12.017167  50.110001
# 2013-12-26  10.250000  14.9  4.616863  0.225000  12.013840  50.040001
# 2013-12-27  10.200000  15.0  4.606508  0.231250  12.077053  50.139999
# 2013-12-30  10.480000  15.3  4.609467  0.235937  12.296636  50.240002
#
#               RS_GOL    RS_CVC   RS_WEGE   RS_MGLU  RS_TOTVS    RS_BOV
# Date
# ...

# %%
print(acoes_df.columns[0:5])
# Out:
# Index(['GOL', 'CVC', 'WEGE', 'MGLU', 'TOTVS'], dtype='object')

# %%
acoes_teste_2 = acoes_df.copy()

# %%
for i in acoes_teste_2.columns[0:5]:
  acoes_teste_2['RL ' + i] = np.log(acoes_teste_2[i] / acoes_teste_2[i].shift(1)) * 100

# %%
acoes_teste_2
# Out:
#                   GOL   CVC      WEGE      MGLU      TOTVS        BOV  \
# Date
# 2010-01-04  26.299999   NaN  2.711538       NaN   7.951558  69.370003
# 2010-01-05  26.080000   NaN  2.705621       NaN   7.818478  69.900002
# 2010-01-06  26.379999   NaN  2.720414       NaN   7.865056  70.300003
# 2010-01-07  26.660000   NaN  2.766272       NaN   7.871710  70.000000
# 2010-01-08  27.950001   NaN  2.866863       NaN   7.948231  69.480003
# ...               ...   ...       ...       ...        ...        ...
# 2013-12-20  10.070000  14.8  4.615384  0.230000  12.040456  49.910000
# 2013-12-23  10.270000  14.7  4.563609  0.229062  12.017167  50.110001
# 2013-12-26  10.250000  14.9  4.616863  0.225000  12.013840  50.040001
# 2013-12-27  10.200000  15.0  4.606508  0.231250  12.077053  50.139999
# 2013-12-30  10.480000  15.3  4.609467  0.235937  12.296636  50.240002
#
#               RS_GOL    RS_CVC   RS_WEGE   RS_MGLU  RS_TOTVS    RS_BOV  \
# Date
# ...
